# %%
import os
import subprocess
import re
import time

# --- Setup Paths (Ensure these environment variables are correctly set in your environment) ---
mopmc_home = os.getenv('MOPMC_HOME')
storm_home = os.getenv('STORM_HOME')
prism_home = os.getenv('PRISM_HOME')

input_folder = os.path.join(os.getcwd(), 'obj_num_eval_input')
d_n_r_model = os.path.join(input_folder, 'dive_and_rise_action_rewards.nm')
d_n_r_property_list = [os.path.join(input_folder, f) for f in os.listdir(input_folder) if f.endswith('.props')]

# Storm can handles number of objectives up to 9
def check_id(f, threshold=10) :
    match = re.search(r'dive_and_rise_prop_(\d+)\.props', os.path.basename(f)) 
    if match:
            prop_id = int(match.group(1)) 
    else:
        print(f"Warning: Could not extract integer ID from prop file: {f}")
    if prop_id < threshold:
        return True
    else:
        return False
            
d_n_r_property_list_below_10 = [f for f in d_n_r_property_list if check_id(f)]
d_n_r_property_list_above_incl_10 = [f for f in d_n_r_property_list if not check_id(f)]


d_n_r_property_10= os.path.join(input_folder, 'dive_and_rise_prop_10.props')
d_n_r_property_5= os.path.join(input_folder, 'dive_and_rise_prop_5.props')
d_n_r_property_6= os.path.join(input_folder, 'dive_and_rise_prop_6.props')
d_n_r_property_7= os.path.join(input_folder, 'dive_and_rise_prop_7.props')
d_n_r_property_8= os.path.join(input_folder, 'dive_and_rise_prop_8.props')
d_n_r_property_9= os.path.join(input_folder, 'dive_and_rise_prop_9.props')
d_n_r_property_60= os.path.join(input_folder, 'dive_and_rise_prop_60.props')
d_n_r_property_80= os.path.join(input_folder, 'dive_and_rise_prop_80.props')
d_n_r_property_100= os.path.join(input_folder, 'dive_and_rise_prop_100.props')

# Construct full executable paths with checks
prism_executable = os.path.join(prism_home, 'bin', 'prism') if prism_home else None
storm_executable = os.path.join(storm_home, 'build', 'bin', 'storm') if storm_home else None
mopmc_executable = os.path.join(mopmc_home, 'build', 'mopmc') if mopmc_home else None

print(f"input folder: {input_folder}")
print(d_n_r_property_list_above_incl_10)
#print(d_n_r_model)
# Out:
# input folder: /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input
# ['/home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_40.props', '/home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_30.props', '/home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_90.props', '/home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_70.props', '/home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_100.props', '/home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_80.props', '/home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_50.props', '/home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_20.props', '/home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_60.props', '/home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_10.props']

# %%
prism_command = f"{prism_executable} {d_n_r_model} {d_n_r_property_100}"
! $prism_command

# %%
storm_command = f"{storm_executable} --prism {d_n_r_model} --prop {d_n_r_property_9}"
! $storm_command

# %%
mopmc_command = f"{mopmc_executable} -m {d_n_r_model} -p {d_n_r_property_80} -q achievability"
! $mopmc_command

# %%
mopmc_command = f"{mopmc_executable} -m {d_n_r_model} -p {d_n_r_property_60} -q achievability -v standard"
! $mopmc_command

# %%
# --- Define the parsing function ---
def parse_output(output_string, tool_name, query):
    """
    Parses the output of the PRISM tool and extracts relevant metrics.
    """
    extracted_data = {}
    states_match = re.search(r"States:\s*(\d+)", output_string, re.IGNORECASE)
    transitions_match = re.search(r"Transitions:\s*(\d+)", output_string, re.IGNORECASE)
    choices_match = re.search(r"Choices:\s*(\d+)", output_string, re.IGNORECASE)
    loop_count_match = re.search(r"MOPMC main loop count:\s*(\d+)", output_string, re.IGNORECASE)
    loop_count_key = query + '_loop_count_' + tool_name

    if states_match:
        extracted_data['States'] = int(states_match.group(1))
    if choices_match:
        extracted_data['Choices'] = int(choices_match.group(1))
    if transitions_match:
        extracted_data['Transitions'] = int(transitions_match.group(1))
    if loop_count_match:
        extracted_data[loop_count_key] = int(loop_count_match.group(1))
    return extracted_data

# %%
def run_tool_and_parse(command_list, parser_function=None, tool_name="Tool", query=None):
    """
    Executes a command and, optionally, parses its output using a provided function.

    Args:
        command_list (list): The command and its arguments as a list.
        tool_name (str): A descriptive name for the tool (e.g., "PRISM", "Storm").
        parser_function (callable, optional): A function that takes the tool's
                                               stdout (string) and returns a dict of extracted data.
                                               If None, no parsing is performed.

    Returns:
        dict: A dictionary containing extracted data and a 'success' flag.
              Returns an empty dictionary if the executable is not found or an error occurs.
    """
    extracted_data = {}

    if not command_list or not command_list[0] or not os.path.exists(command_list[0]):
        print(f"Error: {tool_name} executable not found or command list is invalid. "
              f"Attempted executable: {command_list[0] if command_list else 'None'}")
        return extracted_data

    try:
        print(f"Running {tool_name} command: {' '.join(command_list)}")
        result = subprocess.run(
            command_list,
            capture_output=True,
            text=True,
            check=True
        )
        tool_output = result.stdout
        if parser_function:
            parsed_info = parser_function(tool_output, tool_name, query)
            extracted_data.update(parsed_info) # Add parsed info to the result
    except Exception as e:
        print(f"An unexpected error occurred while running {tool_name}: {e}")

    return extracted_data

# %%
def generate_aq_command_list(executable, model, prop_list, tool_name, query='aq'):
    command_list = []
    if query!='aq':
        raise ValueError(f"Unsupported query: {query}!")
    for prop in prop_list:
        if tool_name == 'mopmc':
            command = [executable, '-m', model, '-p', prop, '-q', 'achievability']            
        elif tool_name == "mopmc_cpu":
            command = [executable, '-m', model, '-p', prop, '-q', 'achievability', '-v', 'standard']
        elif tool_name == "storm":
            command = [executable, '--prism', model, '--prop', prop]
        elif tool_name == "prism":        
            command = [executable, model, prop]
        else:
             raise ValueError(f"Incorrect tool name for achievability query: {tool_name}!")
        command_list.append(command)
    return command_list


def generate_cq_command_list(executable, model, prop_list, tool_name, query='ccq'):
    command_list = []
    
    for prop in prop_list:
        if query=='ccq':
            if tool_name == 'mopmc':
                command = [executable, '-m', model, '-p', prop, '-q', 'convex']            
            elif tool_name == "mopmc_cpu":
                command = [executable, '-m', model, '-p', prop, '-q', 'convex', '-v', 'standard']
            else:
                 raise ValueError(f"Incorrect tool name for convex query: {tool_name}!")
        elif query=='ucq':    
            if tool_name == 'mopmc':
                command = [executable, '-m', model, '-p', prop, '-q', 'convex', '-c', 'n']            
            elif tool_name == "mopmc_cpu":
                command = [executable, '-m', model, '-p', prop, '-q', 'convex', '-c', 'n', '-v', 'standard']
            else:
                 raise ValueError(f"Incorrect tool name for convex query: {tool_name}!")
        else:
            raise ValueError(f"Unsupported query: {query}!")
        command_list.append(command)
    return command_list

# %%
def run_experiment_2(executable, model, prop_list, tool_name, query='aq'):
    results = []
    if query=='aq':
        command_list = generate_aq_command_list(executable, model, prop_list, tool_name, query)
    else:
        command_list = generate_cq_command_list(executable, model, prop_list, tool_name, query)
    runtime_key = query + '_run_time_' + tool_name   
    for prop, command in zip(prop_list, command_list):                    
        start_time = time.perf_counter()
        data = run_tool_and_parse(command, parse_output, tool_name, query)
        end_time = time.perf_counter()
        data[runtime_key] = end_time - start_time        
        match = re.search(r'dive_and_rise_prop_(\d+)\.props', os.path.basename(prop)) 
        prop_id = None
        if match:
            prop_id = int(match.group(1)) 
        else:
            print(f"Warning: Could not extract integer ID from prop file: {prop}")              
        data['obj_num'] = prop_id
        results.append(data)
    return results

# %%
mopmc_gpu_aq_results= run_experiment_2(mopmc_executable, d_n_r_model, d_n_r_property_list, "mopmc", "aq")
mopmc_gpu_aq_results.sort(key= lambda item: item['obj_num'])
print(f"\nMOPMC-GPU Achievability Query Results:")
print(mopmc_gpu_aq_results)
# Out:
# Running mopmc command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_3.props -q achievability
# Running mopmc command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_40.props -q achievability
# Running mopmc command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_30.props -q achievability
# Running mopmc command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_90.props -q achievability
# Running mopmc command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_8.props -q achievability
# Running mopmc command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_70.props -q achievability
# Running mopmc command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_9.props -q achievability
# Running mopmc command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_100.props -q achievability
# Running mopmc command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_80.props -q achievability
# Running mopmc command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_50.props -q achievability
# Running mopmc command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_20.props -q achievability
# Running mopmc command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_60.props -q achievability
# Running mopmc command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_4.props -q achievability
# Running mopmc command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_7.props -q achievability
# Running mopmc command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_6.props -q achievability
# Running mopmc command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_5.props -q achievability
# Running mopmc command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_2.props -q achievability
# Running mopmc command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_10.props -q achievability
#
# MOPMC-GPU Achievability Query Results:
# [{'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'aq_loop_count_mopmc': 2, 'aq_run_time_mopmc': 0.23036847915500402, 'obj_num': 2}, {'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'aq_loop_count_mopmc': 3, 'aq_run_time_mopmc': 0.35980288684368134, 'obj_num': 3}, {'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'aq_loop_count_mopmc': 4, 'aq_run_time_mopmc': 0.268343816511333, 'obj_num': 4}, {'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'aq_loop_count_mopmc': 5, 'aq_run_time_mopmc': 0.26628089882433414, 'obj_num': 5}, {'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'aq_loop_count_mopmc': 6, 'aq_run_time_mopmc': 0.34507775492966175, 'obj_num': 6}, {'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'aq_loop_count_mopmc': 7, 'aq_run_time_mopmc': 0.40660678409039974, 'obj_num': 7}, {'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'aq_loop_count_mopmc': 7, 'aq_run_time_mopmc': 0.3735644118860364, 'obj_num': 8}, {'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'aq_loop_count_mopmc': 9, 'aq_run_time_mopmc': 0.38224304653704166, 'obj_num': 9}, {'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'aq_loop_count_mopmc': 9, 'aq_run_time_mopmc': 0.38214447163045406, 'obj_num': 10}, {'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'aq_loop_count_mopmc': 18, 'aq_run_time_mopmc': 0.8107653642073274, 'obj_num': 20}, {'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'aq_loop_count_mopmc': 20, 'aq_run_time_mopmc': 1.186793682165444, 'obj_num': 30}, {'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'aq_loop_count_mopmc': 20, 'aq_run_time_mopmc': 1.3830315358936787, 'obj_num': 40}, {'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'aq_loop_count_mopmc': 20, 'aq_run_time_mopmc': 1.6040740013122559, 'obj_num': 50}, {'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'aq_loop_count_mopmc': 15, 'aq_run_time_mopmc': 1.4245516704395413, 'obj_num': 60}, {'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'aq_loop_count_mopmc': 17, 'aq_run_time_mopmc': 1.8025811584666371, 'obj_num': 70}, {'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'aq_loop_count_mopmc': 15, 'aq_run_time_mopmc': 1.8576878104358912, 'obj_num': 80}, {'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'aq_loop_count_mopmc': 14, 'aq_run_time_mopmc': 2.013503092341125, 'obj_num': 90}, {'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'aq_loop_count_mopmc': 15, 'aq_run_time_mopmc': 2.205415173433721, 'obj_num': 100}]

# %%
mopmc_cpu_aq_results= run_experiment_2(mopmc_executable, d_n_r_model, d_n_r_property_list, "mopmc_cpu", "aq")
mopmc_cpu_aq_results.sort(key= lambda item: item['obj_num'])
print(f"\nMOPMC-CPU Achievability Query Results:")
print(mopmc_cpu_aq_results)
# Out:
# Running mopmc_cpu command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_3.props -q achievability -v standard
# Running mopmc_cpu command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_40.props -q achievability -v standard
# Running mopmc_cpu command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_30.props -q achievability -v standard
# Running mopmc_cpu command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_90.props -q achievability -v standard
# Running mopmc_cpu command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_8.props -q achievability -v standard
# Running mopmc_cpu command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_70.props -q achievability -v standard
# Running mopmc_cpu command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_9.props -q achievability -v standard
# Running mopmc_cpu command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_100.props -q achievability -v standard
# Running mopmc_cpu command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_80.props -q achievability -v standard
# Running mopmc_cpu command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_50.props -q achievability -v standard
# Running mopmc_cpu command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_20.props -q achievability -v standard
# Running mopmc_cpu command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_60.props -q achievability -v standard
# Running mopmc_cpu command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_4.props -q achievability -v standard
# Running mopmc_cpu command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_7.props -q achievability -v standard
# Running mopmc_cpu command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_6.props -q achievability -v standard
# Running mopmc_cpu command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_5.props -q achievability -v standard
# Running mopmc_cpu command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_2.props -q achievability -v standard
# Running mopmc_cpu command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_10.props -q achievability -v standard
#
# MOPMC-CPU Achievability Query Results:
# [{'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'aq_loop_count_mopmc_cpu': 2, 'aq_run_time_mopmc_cpu': 0.16589324455708265, 'obj_num': 2}, {'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'aq_loop_count_mopmc_cpu': 3, 'aq_run_time_mopmc_cpu': 0.26493257842957973, 'obj_num': 3}, {'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'aq_loop_count_mopmc_cpu': 4, 'aq_run_time_mopmc_cpu': 0.3076258637011051, 'obj_num': 4}, {'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'aq_loop_count_mopmc_cpu': 5, 'aq_run_time_mopmc_cpu': 0.3554506516084075, 'obj_num': 5}, {'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'aq_loop_count_mopmc_cpu': 6, 'aq_run_time_mopmc_cpu': 0.43027939833700657, 'obj_num': 6}, {'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'aq_loop_count_mopmc_cpu': 7, 'aq_run_time_mopmc_cpu': 0.5288979075849056, 'obj_num': 7}, {'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'aq_loop_count_mopmc_cpu': 7, 'aq_run_time_mopmc_cpu': 0.5825856644660234, 'obj_num': 8}, {'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'aq_loop_count_mopmc_cpu': 9, 'aq_run_time_mopmc_cpu': 0.8136349907144904, 'obj_num': 9}, {'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'aq_loop_count_mopmc_cpu': 9, 'aq_run_time_mopmc_cpu': 0.7991865128278732, 'obj_num': 10}, {'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'aq_loop_count_mopmc_cpu': 17, 'aq_run_time_mopmc_cpu': 2.292237144894898, 'obj_num': 20}, {'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'aq_loop_count_mopmc_cpu': 20, 'aq_run_time_mopmc_cpu': 3.593136784620583, 'obj_num': 30}, {'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'aq_loop_count_mopmc_cpu': 6, 'aq_run_time_mopmc_cpu': 1.4689818834885955, 'obj_num': 40}, {'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'aq_loop_count_mopmc_cpu': 20, 'aq_run_time_mopmc_cpu': 5.571389716118574, 'obj_num': 50}, {'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'aq_loop_count_mopmc_cpu': 12, 'aq_run_time_mopmc_cpu': 4.077743815258145, 'obj_num': 60}, {'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'aq_loop_count_mopmc_cpu': 12, 'aq_run_time_mopmc_cpu': 4.804665584117174, 'obj_num': 70}, {'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'aq_loop_count_mopmc_cpu': 5, 'aq_run_time_mopmc_cpu': 2.517828810028732, 'obj_num': 80}, {'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'aq_loop_count_mopmc_cpu': 14, 'aq_run_time_mopmc_cpu': 7.2590287663042545, 'obj_num': 90}, {'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'aq_loop_count_mopmc_cpu': 15, 'aq_run_time_mopmc_cpu': 7.815594890154898, 'obj_num': 100}]

# %%
mopmc_gpu_ccq_results= run_experiment_2(mopmc_executable, d_n_r_model, d_n_r_property_list, "mopmc", "ccq")
mopmc_gpu_ccq_results.sort(key= lambda item: item['obj_num'])
print(f"\nMOPMC-GPU Convex Query Results:")
print(mopmc_gpu_ccq_results)
# Out:
# Running mopmc command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_3.props -q convex
# Running mopmc command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_40.props -q convex
# Running mopmc command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_30.props -q convex
# Running mopmc command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_90.props -q convex
# Running mopmc command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_8.props -q convex
# Running mopmc command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_70.props -q convex
# Running mopmc command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_9.props -q convex
# Running mopmc command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_100.props -q convex
# Running mopmc command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_80.props -q convex
# Running mopmc command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_50.props -q convex
# Running mopmc command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_20.props -q convex
# Running mopmc command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_60.props -q convex
# Running mopmc command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_4.props -q convex
# Running mopmc command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_7.props -q convex
# Running mopmc command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_6.props -q convex
# Running mopmc command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_5.props -q convex
# Running mopmc command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_2.props -q convex
# Running mopmc command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_10.props -q convex
#
# MOPMC-GPU Convex Query Results:
# [{'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'ccq_loop_count_mopmc': 3, 'ccq_run_time_mopmc': 0.24386932514607906, 'obj_num': 2}, {'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'ccq_loop_count_mopmc': 3, 'ccq_run_time_mopmc': 0.2850064616650343, 'obj_num': 3}, {'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'ccq_loop_count_mopmc': 3, 'ccq_run_time_mopmc': 0.31571271270513535, 'obj_num': 4}, {'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'ccq_loop_count_mopmc': 3, 'ccq_run_time_mopmc': 0.32819984667003155, 'obj_num': 5}, {'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'ccq_loop_count_mopmc': 3, 'ccq_run_time_mopmc': 0.23957956209778786, 'obj_num': 6}, {'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'ccq_loop_count_mopmc': 22, 'ccq_run_time_mopmc': 0.6657983874902129, 'obj_num': 7}, {'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'ccq_loop_count_mopmc': 3, 'ccq_run_time_mopmc': 0.3549363799393177, 'obj_num': 8}, {'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'ccq_loop_count_mopmc': 15, 'ccq_run_time_mopmc': 0.49843334034085274, 'obj_num': 9}, {'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'ccq_loop_count_mopmc': 24, 'ccq_run_time_mopmc': 0.7245425032451749, 'obj_num': 10}, {'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'ccq_loop_count_mopmc': 18, 'ccq_run_time_mopmc': 0.9623071728274226, 'obj_num': 20}, {'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'ccq_loop_count_mopmc': 29, 'ccq_run_time_mopmc': 1.67934035602957, 'obj_num': 30}, {'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'ccq_loop_count_mopmc': 45, 'ccq_run_time_mopmc': 2.77860448602587, 'obj_num': 40}, {'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'ccq_loop_count_mopmc': 168, 'ccq_run_time_mopmc': 12.2766874441877, 'obj_num': 50}, {'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'ccq_loop_count_mopmc': 45, 'ccq_run_time_mopmc': 3.7775355437770486, 'obj_num': 60}, {'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'ccq_loop_count_mopmc': 62, 'ccq_run_time_mopmc': 5.7511093355715275, 'obj_num': 70}, {'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'ccq_loop_count_mopmc': 67, 'ccq_run_time_mopmc': 7.325758397579193, 'obj_num': 80}, {'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'ccq_loop_count_mopmc': 200, 'ccq_run_time_mopmc': 22.563803307712078, 'obj_num': 90}, {'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'ccq_loop_count_mopmc': 200, 'ccq_run_time_mopmc': 26.49457769934088, 'obj_num': 100}]

# %%
mopmc_cpu_ccq_results= run_experiment_2(mopmc_executable, d_n_r_model, d_n_r_property_list, "mopmc_cpu", "ccq")
mopmc_cpu_ccq_results.sort(key= lambda item: item['obj_num'])
print(f"\nMOPMC-CPU Convex Query Results:")
print(mopmc_cpu_ccq_results)
# Out:
# Running mopmc_cpu command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_3.props -q convex -v standard
# Running mopmc_cpu command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_40.props -q convex -v standard
# Running mopmc_cpu command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_30.props -q convex -v standard
# Running mopmc_cpu command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_90.props -q convex -v standard
# Running mopmc_cpu command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_8.props -q convex -v standard
# Running mopmc_cpu command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_70.props -q convex -v standard
# Running mopmc_cpu command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_9.props -q convex -v standard
# Running mopmc_cpu command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_100.props -q convex -v standard
# Running mopmc_cpu command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_80.props -q convex -v standard
# Running mopmc_cpu command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_50.props -q convex -v standard
# Running mopmc_cpu command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_20.props -q convex -v standard
# Running mopmc_cpu command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_60.props -q convex -v standard
# Running mopmc_cpu command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_4.props -q convex -v standard
# Running mopmc_cpu command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_7.props -q convex -v standard
# Running mopmc_cpu command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_6.props -q convex -v standard
# Running mopmc_cpu command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_5.props -q convex -v standard
# Running mopmc_cpu command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_2.props -q convex -v standard
# Running mopmc_cpu command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_10.props -q convex -v standard
#
# MOPMC-CPU Convex Query Results:
# [{'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'ccq_loop_count_mopmc_cpu': 3, 'ccq_run_time_mopmc_cpu': 0.1844176584854722, 'obj_num': 2}, {'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'ccq_loop_count_mopmc_cpu': 3, 'ccq_run_time_mopmc_cpu': 0.2549472963437438, 'obj_num': 3}, {'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'ccq_loop_count_mopmc_cpu': 3, 'ccq_run_time_mopmc_cpu': 0.21491996198892593, 'obj_num': 4}, {'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'ccq_loop_count_mopmc_cpu': 3, 'ccq_run_time_mopmc_cpu': 0.22631210926920176, 'obj_num': 5}, {'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'ccq_loop_count_mopmc_cpu': 3, 'ccq_run_time_mopmc_cpu': 0.23573634400963783, 'obj_num': 6}, {'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'ccq_loop_count_mopmc_cpu': 3, 'ccq_run_time_mopmc_cpu': 0.28865651600062847, 'obj_num': 7}, {'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'ccq_loop_count_mopmc_cpu': 20, 'ccq_run_time_mopmc_cpu': 1.4472320610657334, 'obj_num': 8}, {'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'ccq_loop_count_mopmc_cpu': 3, 'ccq_run_time_mopmc_cpu': 0.3214428462088108, 'obj_num': 9}, {'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'ccq_loop_count_mopmc_cpu': 23, 'ccq_run_time_mopmc_cpu': 1.8945906721055508, 'obj_num': 10}, {'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'ccq_loop_count_mopmc_cpu': 22, 'ccq_run_time_mopmc_cpu': 2.8587146531790495, 'obj_num': 20}, {'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'ccq_loop_count_mopmc_cpu': 29, 'ccq_run_time_mopmc_cpu': 5.1852640602737665, 'obj_num': 30}, {'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'ccq_loop_count_mopmc_cpu': 46, 'ccq_run_time_mopmc_cpu': 10.435532242059708, 'obj_num': 40}, {'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'ccq_loop_count_mopmc_cpu': 179, 'ccq_run_time_mopmc_cpu': 49.9186134301126, 'obj_num': 50}, {'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'ccq_loop_count_mopmc_cpu': 40, 'ccq_run_time_mopmc_cpu': 12.596513349562883, 'obj_num': 60}, {'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'ccq_loop_count_mopmc_cpu': 53, 'ccq_run_time_mopmc_cpu': 19.52481955382973, 'obj_num': 70}, {'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'ccq_loop_count_mopmc_cpu': 82, 'ccq_run_time_mopmc_cpu': 34.96304521616548, 'obj_num': 80}, {'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'ccq_loop_count_mopmc_cpu': 200, 'ccq_run_time_mopmc_cpu': 107.60111788660288, 'obj_num': 90}, {'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'ccq_loop_count_mopmc_cpu': 194, 'ccq_run_time_mopmc_cpu': 103.39038797840476, 'obj_num': 100}]

# %%
mopmc_gpu_ucq_results= run_experiment_2(mopmc_executable, d_n_r_model, d_n_r_property_list, "mopmc", "ucq")
mopmc_gpu_ucq_results.sort(key= lambda item: item['obj_num'])
print(f"\nMOPMC-GPU (Unconstrained) Convex Query Results:")
print(mopmc_gpu_ucq_results)

# %%
mopmc_cpu_ucq_results= run_experiment_2(mopmc_executable, d_n_r_model, d_n_r_property_list, "mopmc_cpu", "ucq")
mopmc_cpu_ucq_results.sort(key= lambda item: item['obj_num'])
print(f"\nMOPMC-CPU (Unconstrained) Convex Query Results:")
print(mopmc_cpu_ucq_results)

# %%
# for storm, run up to objective number < 10
storm_results= run_experiment_2(storm_executable, d_n_r_model, d_n_r_property_list_below_10, "storm")
storm_results.sort(key= lambda item: item['obj_num'])
print(f"\nStorm Results:")
print(storm_results)
# Out:
# Running storm command: /home/guoxin/Downloads/storm/build/bin/storm --prism /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm --prop /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_3.props
# Running storm command: /home/guoxin/Downloads/storm/build/bin/storm --prism /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm --prop /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_8.props
# Running storm command: /home/guoxin/Downloads/storm/build/bin/storm --prism /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm --prop /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_9.props
# Running storm command: /home/guoxin/Downloads/storm/build/bin/storm --prism /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm --prop /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_4.props
# Running storm command: /home/guoxin/Downloads/storm/build/bin/storm --prism /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm --prop /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_7.props
# Running storm command: /home/guoxin/Downloads/storm/build/bin/storm --prism /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm --prop /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_6.props
# Running storm command: /home/guoxin/Downloads/storm/build/bin/storm --prism /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm --prop /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_5.props
# Running storm command: /home/guoxin/Downloads/storm/build/bin/storm --prism /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm --prop /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_2.props
#
# Storm Results:
# [{'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'aq_run_time_storm': 0.11239305604249239, 'obj_num': 2}, {'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'aq_run_time_storm': 0.2259220564737916, 'obj_num': 3}, {'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'aq_run_time_storm': 0.2018855009227991, 'obj_num': 4}, {'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'aq_run_time_storm': 0.3840728783980012, 'obj_num': 5}, {'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'aq_run_time_storm': 0.809201025404036, 'obj_num': 6}, {'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'aq_run_time_storm': 3.9427685271948576, 'obj_num': 7}, {'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'aq_run_time_storm': 24.630094551481307, 'obj_num': 8}, {'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'aq_run_time_storm': 150.77757746633142, 'obj_num': 9}]

# %%
prism_results = run_experiment_2(prism_executable, d_n_r_model, d_n_r_property_list, "prism")
prism_results.sort(key= lambda item: item['obj_num'])
print(f"\nPRISM Results:")
print(prism_results)
# Out:
# Running prism command: /home/guoxin/Downloads/prism-4.4-linux64/bin/prism /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_3.props
# Running prism command: /home/guoxin/Downloads/prism-4.4-linux64/bin/prism /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_40.props
# Running prism command: /home/guoxin/Downloads/prism-4.4-linux64/bin/prism /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_30.props
# Running prism command: /home/guoxin/Downloads/prism-4.4-linux64/bin/prism /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_90.props
# Running prism command: /home/guoxin/Downloads/prism-4.4-linux64/bin/prism /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_8.props
# Running prism command: /home/guoxin/Downloads/prism-4.4-linux64/bin/prism /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_70.props
# Running prism command: /home/guoxin/Downloads/prism-4.4-linux64/bin/prism /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_9.props
# Running prism command: /home/guoxin/Downloads/prism-4.4-linux64/bin/prism /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_100.props
# Running prism command: /home/guoxin/Downloads/prism-4.4-linux64/bin/prism /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_80.props
# Running prism command: /home/guoxin/Downloads/prism-4.4-linux64/bin/prism /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_50.props
# Running prism command: /home/guoxin/Downloads/prism-4.4-linux64/bin/prism /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_20.props
# Running prism command: /home/guoxin/Downloads/prism-4.4-linux64/bin/prism /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_60.props
# Running prism command: /home/guoxin/Downloads/prism-4.4-linux64/bin/prism /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_4.props
# Running prism command: /home/guoxin/Downloads/prism-4.4-linux64/bin/prism /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_7.props
# Running prism command: /home/guoxin/Downloads/prism-4.4-linux64/bin/prism /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_6.props
# Running prism command: /home/guoxin/Downloads/prism-4.4-linux64/bin/prism /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_5.props
# Running prism command: /home/guoxin/Downloads/prism-4.4-linux64/bin/prism /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_2.props
# Running prism command: /home/guoxin/Downloads/prism-4.4-linux64/bin/prism /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_action_rewards.nm /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/obj_num_eval_input/dive_and_rise_prop_10.props
#
# PRISM Results:
# [{'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'aq_run_time_prism': 1.4125673873350024, 'obj_num': 2}, {'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'aq_run_time_prism': 1.356066906824708, 'obj_num': 3}, {'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'aq_run_time_prism': 1.3205732833594084, 'obj_num': 4}, {'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'aq_run_time_prism': 1.3743224944919348, 'obj_num': 5}, {'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'aq_run_time_prism': 1.5190660739317536, 'obj_num': 6}, {'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'aq_run_time_prism': 1.9529966749250889, 'obj_num': 7}, {'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'aq_run_time_prism': 2.3100407095625997, 'obj_num': 8}, {'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'aq_run_time_prism': 2.742024928331375, 'obj_num': 9}, {'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'aq_run_time_prism': 3.0249802730977535, 'obj_num': 10}, {'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'aq_run_time_prism': 10.48944849986583, 'obj_num': 20}, {'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'aq_run_time_prism': 18.083813392557204, 'obj_num': 30}, {'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'aq_run_time_prism': 29.786909541115165, 'obj_num': 40}, {'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'aq_run_time_prism': 42.057052162475884, 'obj_num': 50}, {'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'aq_run_time_prism': 24.92651939764619, 'obj_num': 60}, {'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'aq_run_time_prism': 31.44956205226481, 'obj_num': 70}, {'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'aq_run_time_prism': 41.57862431649119, 'obj_num': 80}, {'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'aq_run_time_prism': 49.79016657080501, 'obj_num': 90}, {'States': 15051, 'Choices': 30001, 'Transitions': 89203, 'aq_run_time_prism': 49.7226393641904, 'obj_num': 100}]

# %%
from itertools import zip_longest
combined_results= []

for d0, d1, d2, d3, d4, d5 in zip_longest(storm_results, prism_results, 
                                          mopmc_gpu_aq_results, mopmc_cpu_aq_results,
                                          mopmc_gpu_ccq_results, mopmc_cpu_ccq_results,
                                          fillvalue={}):
    combined_dict = {}
    combined_dict.update(d0)
    combined_dict.update(d1)
    combined_dict.update(d2)
    combined_dict.update(d3)
    combined_dict.update(d4)
    combined_dict.update(d5)
    combined_results.append(combined_dict)

import pandas as pd
combined_results_df = pd.DataFrame(combined_results)
print(f"current column names: {combined_results_df.columns}")
combined_results_df['ccq_run_time_mopmc_per_it'] = combined_results_df['ccq_run_time_mopmc'] / combined_results_df['ccq_loop_count_mopmc']
combined_results_df['ccq_run_time_mopmc_cpu_per_it'] = combined_results_df['ccq_run_time_mopmc_cpu'] / combined_results_df['ccq_loop_count_mopmc_cpu']
new_column_order = ['obj_num', 'States', 'Choices', 'Transitions', 
                    'aq_run_time_storm', 'aq_run_time_prism', 
                    'aq_run_time_mopmc', 'aq_run_time_mopmc_cpu', 
                    'ccq_run_time_mopmc', 'ccq_loop_count_mopmc', 'ccq_run_time_mopmc_per_it', 
                    'ccq_run_time_mopmc_cpu', 'ccq_loop_count_mopmc_cpu', 'ccq_run_time_mopmc_cpu_per_it']
combined_results_df = combined_results_df[new_column_order]

num_columns = ['aq_run_time_storm', 'aq_run_time_prism', 'aq_run_time_mopmc',
       'aq_run_time_mopmc_cpu', 'ccq_run_time_mopmc',
       'ccq_run_time_mopmc_cpu', 'ccq_run_time_mopmc_per_it', 'ccq_run_time_mopmc_cpu_per_it']
combined_results_df[num_columns] = combined_results_df[num_columns].round(2)
print(combined_results_df)
# Out:
# current column names: Index(['States', 'Choices', 'Transitions', 'aq_run_time_storm', 'obj_num',
#        'aq_run_time_prism', 'aq_loop_count_mopmc', 'aq_run_time_mopmc',
#        'aq_loop_count_mopmc_cpu', 'aq_run_time_mopmc_cpu',
#        'ccq_loop_count_mopmc', 'ccq_run_time_mopmc',
#        'ccq_loop_count_mopmc_cpu', 'ccq_run_time_mopmc_cpu'],
#       dtype='object')
#     obj_num  States  Choices  Transitions  aq_run_time_storm  \
# 0         2   15051    30001        89203               0.11
# 1         3   15051    30001        89203               0.23
# 2         4   15051    30001        89203               0.20
# 3         5   15051    30001        89203               0.38
# 4         6   15051    30001        89203               0.81
# 5         7   15051    30001        89203               3.94
# 6         8   15051    30001        89203              24.63
# 7         9   15051    30001        89203             150.78
# 8        10   15051    30001        89203                NaN
# 9        20   15051    30001        89203                NaN
# 10       30   15051    30001        89203                NaN
# 11       40   15051    30001        89203                NaN
# 12       50   15051    30001        89203                NaN
# 13       60   15051    30001        89203                NaN
# 14       70   15051    30001        89203                NaN
# 15       80   15051    30001        89203                NaN
# 16       90   15051    30001        89203                NaN
# 17      100   15051    30001        89203                NaN
#
#     aq_run_time_prism  aq_run_time_mopmc  aq_run_time_mopmc_cpu  \
# 0                1.41               0.23                   0.17
# 1                1.36               0.36                   0.26
# 2                1.32               0.27                   0.31
# 3                1.37               0.27                   0.36
# 4                1.52               0.35                   0.43
# 5                1.95               0.41                   0.53
# 6                2.31               0.37                   0.58
# 7                2.74               0.38                   0.81
# 8                3.02               0.38                   0.80
# 9               10.49               0.81                   2.29
# 10              18.08               1.19                   3.59
# 11              29.79               1.38                   1.47
# 12              42.06               1.60                   5.57
# 13              24.93               1.42                   4.08
# 14              31.45               1.80                   4.80
# 15              41.58               1.86                   2.52
# 16              49.79               2.01                   7.26
# 17              49.72               2.21                   7.82
#
#     ccq_run_time_mopmc  ccq_loop_count_mopmc  ccq_run_time_mopmc_per_it  \
# 0                 0.24                     3                       0.08
# 1                 0.29                     3                       0.10
# 2                 0.32                     3                       0.11
# 3                 0.33                     3                       0.11
# 4                 0.24                     3                       0.08
# 5                 0.67                    22                       0.03
# 6                 0.35                     3                       0.12
# 7                 0.50                    15                       0.03
# 8                 0.72                    24                       0.03
# 9                 0.96                    18                       0.05
# 10                1.68                    29                       0.06
# 11                2.78                    45                       0.06
# 12               12.28                   168                       0.07
# 13                3.78                    45                       0.08
# 14                5.75                    62                       0.09
# 15                7.33                    67                       0.11
# 16               22.56                   200                       0.11
# 17               26.49                   200                       0.13
#
#     ccq_run_time_mopmc_cpu  ccq_loop_count_mopmc_cpu  \
# 0                     0.18                         3
# 1                     0.25                         3
# 2                     0.21                         3
# 3                     0.23                         3
# 4                     0.24                         3
# 5                     0.29                         3
# 6                     1.45                        20
# 7                     0.32                         3
# 8                     1.89                        23
# 9                     2.86                        22
# 10                    5.19                        29
# 11                   10.44                        46
# 12                   49.92                       179
# 13                   12.60                        40
# 14                   19.52                        53
# 15                   34.96                        82
# 16                  107.60                       200
# 17                  103.39                       194
#
#     ccq_run_time_mopmc_cpu_per_it
# 0                            0.06
# 1                            0.08
# 2                            0.07
# 3                            0.08
# 4                            0.08
# 5                            0.10
# 6                            0.07
# 7                            0.11
# 8                            0.08
# 9                            0.13
# 10                           0.18
# 11                           0.23
# 12                           0.28
# 13                           0.31
# 14                           0.37
# 15                           0.43
# 16                           0.54
# 17                           0.53
