# %%
import os
import subprocess
import re
import time

# --- Setup Paths (Ensure these environment variables are correctly set in your environment) ---
mopmc_home = os.getenv('MOPMC_HOME')
storm_home = os.getenv('STORM_HOME')
prism_home = os.getenv('PRISM_HOME')

input_folder = os.path.join(os.getcwd(), 'model_size_eval_input')
switch_model_list = [os.path.join(input_folder, f) for f in os.listdir(input_folder) if f.endswith('.prism')]
switch_model_20 = os.path.join(input_folder, 'switch_model_20.prism')
switch_property = os.path.join(input_folder, 'switch_prop_achievable.props')

# Construct full executable paths with checks
prism_executable = os.path.join(prism_home, 'bin', 'prism') if prism_home else None
storm_executable = os.path.join(storm_home, 'build', 'bin', 'storm') if storm_home else None
mopmc_executable = os.path.join(mopmc_home, 'build', 'mopmc') if mopmc_home else None

switch_model_list
# Out:
# ['/home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/model_size_eval_input/switch_model_20.prism',
#  '/home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/model_size_eval_input/switch_model_120.prism',
#  '/home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/model_size_eval_input/switch_model_200.prism',
#  '/home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/model_size_eval_input/switch_model_100.prism',
#  '/home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/model_size_eval_input/switch_model_140.prism',
#  '/home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/model_size_eval_input/switch_model_80.prism',
#  '/home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/model_size_eval_input/switch_model_60.prism',
#  '/home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/model_size_eval_input/switch_model_180.prism',
#  '/home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/model_size_eval_input/switch_model_160.prism',
#  '/home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/model_size_eval_input/switch_model_40.prism']

# %%
#prism_command_swtich_model = f"{prism_executable} {switch_model} {switch_property}"
#! $prism_command_swtich_model
#storm_command_swtich_model = f"{storm_executable} --prism {switch_model} --prop {switch_property}"
#! $storm_command_swtich_model
#mopmc_command_switch_model = f"{mopmc_executable} -m {switch_model} -p {switch_property} -q achievability"
#! $mopmc_command_switch_model
# Out:
# PRISM
# =====
#
# Version: 4.4
# Date: Thu May 29 15:24:57 AEST 2025
# Hostname: guoxin-Precision-3660
# Memory limits: cudd=1g, java(heap)=1g
# Command line: prism /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/switch_model_20.prism /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/switch_prop_achievable.props
#
# Parsing model file "/home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/switch_model_20.prism"...
#
# Parsing properties file "/home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/switch_prop_achievable.props"...
#
# 1 property:
# (1) multi(R{"ctrl_cost"}<=1.895 [ C ], R{"headway_cost"}<=0.573 [ C ], R{"ttc_cost"}<=0.235 [ C ], R{"onlane_cost"}<=0.235 [ C ])
#
# Type:        MDP
# Modules:     swtich
# Variables:   loc ctrl conf ct cc headway ttc onlane
#
# ---------------------------------------------------------------------
#
# Model checking: multi(R{"ctrl_cost"}<=1.895 [ C ], R{"headway_cost"}<=0.573 [ C ], R{"ttc_cost"}<=0.235 [ C ], R{"onlane_cost"}<=0.235 [ C ])
#
# Building model...
#
# Computing reachable states...
#
# Reachability (BFS): 52 iterations in 0.01 seconds (average 0.000135, setup 0.00)
#
# Time for model construction: 0.017 seconds.
#
# Warning: Deadlocks detected and fixed in 640 states
#
# Type:        MDP
# States:      19317 (1 initial)
# Transitions: 68033
# Choices:     19377
#
# Transition matrix: 3050 nodes (46 terminal), 68033 minterms, vars: 20r/20c/2nd
# Total time for product construction: 0.0 seconds.
#
# States:      19317 (1 initial)
# Transitions: 68033
# Choices:     19377
#
# Transition matrix: 3050 nodes (46 terminal), 68033 minterms, vars: 20r/20c/2nd
#
# Prob0A: 1 iterations in 0.00 seconds (average 0.001000, setup 0.00)
#
# yes = 0, no = 0, maybe = 19317
#
# Computing remaining probabilities...
# Switching engine since only sparse engine currently supports this computation...
# Engine: Sparse
# Iterative method: 100 iterations in 0.07 seconds (average 0.000690, setup 0.00)
# Optimal value for weights [0.644997,0.195031,0.079986,0.079986] from initial state: -1.335556
# Iterative method: 87 iterations in 0.06 seconds (average 0.000690, setup 0.00)
# Optimal value for weights [0.000000,1.000000,0.000000,0.000000] from initial state: -0.572864
# The value iteration(s) took 0.138 seconds altogether.
# Number of weight vectors used: 2
# Multi-objective value iterations took 0.138 s.
#
# Property satisfied in 1 of 1 initial states.
#
# Time for model checking: 0.204 seconds.
#
# Result: true (property satisfied in the initial state)
#
# ---------------------------------------------------------------------
#
# Note: There was 1 warning during computation.
#
# Storm 1.8.2 (dev)
#
# Date: Thu May 29 15:24:58 2025
# Command line arguments: --prism /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/switch_model_20.prism --prop /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/switch_prop_achievable.props
# Current working directory: /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation
#
# Time for model input parsing: 0.003s.
#
# Time for model construction: 0.045s.
#
# --------------------------------------------------------------
# Model type: 	MDP (sparse)
# States: 	19317
# Transitions: 	68033
# Choices: 	19377
# Reward Models:  ttc_cost, onlane_cost, headway_cost, ctrl_cost
# State Labels: 	2 labels
#    * deadlock -> 640 item(s)
#    * init -> 1 item(s)
# Choice Labels: 	none
# --------------------------------------------------------------
#
# Model checking property "1": multi(R[exp]{"ctrl_cost"}<=379/200 [C], R[exp]{"headway_cost"}<=573/1000 [C], R[exp]{"ttc_cost"}<=47/200 [C], R[exp]{"onlane_cost"}<=47/200 [C]) ...
# Result (for initial states): true
#
# Time for model checking: 0.095s.

# %%
# --- Define the parsing function ---
def parse_output(output_string, tool_name, query):
    """
    Parses the output of the PRISM tool and extracts relevant metrics.
    """
    extracted_data = {}
    states_match = re.search(r"States:\s*(\d+)", output_string, re.IGNORECASE)
    transitions_match = re.search(r"Transitions:\s*(\d+)", output_string, re.IGNORECASE)
    choices_match = re.search(r"Choices:\s*(\d+)", output_string, re.IGNORECASE)
    loop_count_match = re.search(r"MOPMC main loop count:\s*(\d+)", output_string, re.IGNORECASE)
    loop_count_key = query + '_loop_count_' + tool_name
    
    if states_match:
        extracted_data['States'] = int(states_match.group(1))
    if choices_match:
        extracted_data['Choices'] = int(choices_match.group(1))
    if transitions_match:
        extracted_data['Transitions'] = int(transitions_match.group(1))
    if loop_count_match:
        extracted_data[loop_count_key] = int(loop_count_match.group(1))
    return extracted_data

# %%
def run_tool_and_parse(command_list, parser_function=None, tool_name="Tool", query=None):
    """
    Executes a command and, optionally, parses its output using a provided function.

    Args:
        command_list (list): The command and its arguments as a list.
        tool_name (str): A descriptive name for the tool (e.g., "PRISM", "Storm").
        parser_function (callable, optional): A function that takes the tool's
                                               stdout (string) and returns a dict of extracted data.
                                               If None, no parsing is performed.

    Returns:
        dict: A dictionary containing extracted data and a 'success' flag.
              Returns an empty dictionary if the executable is not found or an error occurs.
    """
    extracted_data = {}

    if not command_list or not command_list[0] or not os.path.exists(command_list[0]):
        print(f"Error: {tool_name} executable not found or command list is invalid. "
              f"Attempted executable: {command_list[0] if command_list else 'None'}")
        return extracted_data

    try:
        print(f"Running {tool_name} command: {' '.join(command_list)}")
        result = subprocess.run(
            command_list,
            capture_output=True,
            text=True,
            check=True
        )
        tool_output = result.stdout
        if parser_function:
            parsed_info = parser_function(tool_output, tool_name, query)
            extracted_data.update(parsed_info) # Add parsed info to the result
    except Exception as e:
        print(f"An unexpected error occurred while running {tool_name}: {e}")

    return extracted_data

# %%
def generate_aq_command_list(executable, model_list, prop, tool_name, query='aq'):
    command_list = []
    if query!='aq':
        raise ValueError(f"Unsupported query: {query}!")
    for model in model_list:
        if tool_name == 'mopmc':
            command = [executable, '-m', model, '-p', prop, '-q', 'achievability']            
        elif tool_name == "mopmc_cpu":
            command = [executable, '-m', model, '-p', prop, '-q', 'achievability', '-v', 'standard']
        elif tool_name == "storm":
            command = [executable, '--prism', model, '--prop', prop]
        elif tool_name == "prism":        
            command = [executable, model, prop]
        else:
             raise ValueError(f"Incorrect tool name for achievability query: {tool_name}!")
        command_list.append(command)
    return command_list


def generate_cq_command_list(executable, model_list, prop, tool_name, query='ccq'):
    command_list = []
    
    for model in model_list:
        if query=='ccq':
            if tool_name == 'mopmc':
                command = [executable, '-m', model, '-p', prop, '-q', 'convex']            
            elif tool_name == "mopmc_cpu":
                command = [executable, '-m', model, '-p', prop, '-q', 'convex', '-v', 'standard']
            else:
                 raise ValueError(f"Incorrect tool name for convex query: {tool_name}!")
        elif query=='ucq':    
            if tool_name == 'mopmc':
                command = [executable, '-m', model, '-p', prop, '-q', 'convex', '-c', 'n']            
            elif tool_name == "mopmc_cpu":
                command = [executable, '-m', model, '-p', prop, '-q', 'convex', '-c', 'n', '-v', 'standard']
            else:
                 raise ValueError(f"Incorrect tool name for convex query: {tool_name}!")
        else:
            raise ValueError(f"Unsupported query: {query}!")
        command_list.append(command)
    return command_list

    
def run_experiment(executable, model_list, prop, tool_name, query='aq'):
    results = []
    if query=='aq':
        command_list = generate_aq_command_list(executable, model_list, prop, tool_name, query)
    else:
        command_list = generate_cq_command_list(executable, model_list, prop, tool_name, query)
    runtime_key = query + '_run_time_' + tool_name   
    for switch_model, command in zip(model_list, command_list):                    
        start_time = time.perf_counter()
        data = run_tool_and_parse(command, parse_output, tool_name, query)
        end_time = time.perf_counter()
        data[runtime_key] = end_time - start_time        
        match = re.search(r'switch_model_(\d+)\.prism', os.path.basename(switch_model))
        model_id = None
        if match:
            model_id = int(match.group(1)) 
        else:
            print(f"Warning: Could not extract integer ID from model: {switch_model}")              
        data['max_timesteps'] = model_id
        results.append(data)
    return results

# %%
mopmc_gpu_aq_results= run_experiment(mopmc_executable, switch_model_list, switch_property, "mopmc", "aq")
mopmc_gpu_aq_results.sort(key= lambda item: item['max_timesteps'])
print(f"\nMOPMC-GPU Achievability Query Results:")
print(mopmc_gpu_aq_results)
# Out:
# Running mopmc command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/model_size_eval_input/switch_model_20.prism -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/model_size_eval_input/switch_prop_achievable.props -q achievability
# Running mopmc command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/model_size_eval_input/switch_model_120.prism -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/model_size_eval_input/switch_prop_achievable.props -q achievability
# Running mopmc command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/model_size_eval_input/switch_model_200.prism -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/model_size_eval_input/switch_prop_achievable.props -q achievability
# Running mopmc command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/model_size_eval_input/switch_model_100.prism -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/model_size_eval_input/switch_prop_achievable.props -q achievability
# Running mopmc command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/model_size_eval_input/switch_model_140.prism -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/model_size_eval_input/switch_prop_achievable.props -q achievability
# Running mopmc command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/model_size_eval_input/switch_model_80.prism -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/model_size_eval_input/switch_prop_achievable.props -q achievability
# Running mopmc command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/model_size_eval_input/switch_model_60.prism -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/model_size_eval_input/switch_prop_achievable.props -q achievability
# Running mopmc command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/model_size_eval_input/switch_model_180.prism -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/model_size_eval_input/switch_prop_achievable.props -q achievability
# Running mopmc command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/model_size_eval_input/switch_model_160.prism -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/model_size_eval_input/switch_prop_achievable.props -q achievability
# Running mopmc command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/model_size_eval_input/switch_model_40.prism -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/model_size_eval_input/switch_prop_achievable.props -q achievability
#
# MOPMC-GPU Achievability Query Results:
# [{'States': 19317, 'Choices': 19377, 'Transitions': 68033, 'aq_loop_count_mopmc': 1, 'aq_run_time_mopmc': 0.34843981452286243, 'max_timesteps': 20}, {'States': 76937, 'Choices': 77057, 'Transitions': 276673, 'aq_loop_count_mopmc': 1, 'aq_run_time_mopmc': 0.4496399173513055, 'max_timesteps': 40}, {'States': 172957, 'Choices': 173137, 'Transitions': 626113, 'aq_loop_count_mopmc': 1, 'aq_run_time_mopmc': 0.9380011511966586, 'max_timesteps': 60}, {'States': 307377, 'Choices': 307617, 'Transitions': 1116353, 'aq_loop_count_mopmc': 1, 'aq_run_time_mopmc': 1.7026363648474216, 'max_timesteps': 80}, {'States': 480197, 'Choices': 480497, 'Transitions': 1747393, 'aq_loop_count_mopmc': 1, 'aq_run_time_mopmc': 2.734246727079153, 'max_timesteps': 100}, {'States': 691417, 'Choices': 691777, 'Transitions': 2519233, 'aq_loop_count_mopmc': 1, 'aq_run_time_mopmc': 4.271516497246921, 'max_timesteps': 120}, {'States': 941037, 'Choices': 941457, 'Transitions': 3431873, 'aq_loop_count_mopmc': 1, 'aq_run_time_mopmc': 6.140992366708815, 'max_timesteps': 140}, {'States': 1229057, 'Choices': 1229537, 'Transitions': 4485313, 'aq_loop_count_mopmc': 1, 'aq_run_time_mopmc': 8.817500781267881, 'max_timesteps': 160}, {'States': 1555477, 'Choices': 1556017, 'Transitions': 5679553, 'aq_loop_count_mopmc': 1, 'aq_run_time_mopmc': 12.070667770691216, 'max_timesteps': 180}, {'States': 1920297, 'Choices': 1920897, 'Transitions': 7014593, 'aq_loop_count_mopmc': 1, 'aq_run_time_mopmc': 16.170903217978776, 'max_timesteps': 200}]

# %%
mopmc_cpu_aq_results= run_experiment(mopmc_executable, switch_model_list, switch_property, "mopmc_cpu", "aq")
mopmc_cpu_aq_results.sort(key= lambda item: item['max_timesteps'])
print(f"\nMOPMC-CPU Achievability Query Results:")
print(mopmc_cpu_aq_results)
# Out:
# Running mopmc_cpu command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m switch_model_20.prism -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/switch_prop_achievable.props -q achievability -v standard
# Running mopmc_cpu command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m switch_model_120.prism -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/switch_prop_achievable.props -q achievability -v standard
# Running mopmc_cpu command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m switch_model_200.prism -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/switch_prop_achievable.props -q achievability -v standard
# Running mopmc_cpu command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m switch_model_100.prism -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/switch_prop_achievable.props -q achievability -v standard
# Running mopmc_cpu command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m switch_model_140.prism -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/switch_prop_achievable.props -q achievability -v standard
# Running mopmc_cpu command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m switch_model_80.prism -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/switch_prop_achievable.props -q achievability -v standard
# Running mopmc_cpu command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m switch_model_60.prism -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/switch_prop_achievable.props -q achievability -v standard
# Running mopmc_cpu command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m switch_model_180.prism -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/switch_prop_achievable.props -q achievability -v standard
# Running mopmc_cpu command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m switch_model_160.prism -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/switch_prop_achievable.props -q achievability -v standard
# Running mopmc_cpu command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m switch_model_40.prism -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/switch_prop_achievable.props -q achievability -v standard
#
# MOPMC-CPU Achievability Query Results:
# [{'States': 19317, 'Choices': 19377, 'Transitions': 68033, 'aq_run_time_mopmc_cpu': 0.17234523314982653, 'max_timesteps': 20}, {'States': 76937, 'Choices': 77057, 'Transitions': 276673, 'aq_run_time_mopmc_cpu': 0.4858173839747906, 'max_timesteps': 40}, {'States': 172957, 'Choices': 173137, 'Transitions': 626113, 'aq_run_time_mopmc_cpu': 1.2534190518781543, 'max_timesteps': 60}, {'States': 307377, 'Choices': 307617, 'Transitions': 1116353, 'aq_run_time_mopmc_cpu': 2.70249598659575, 'max_timesteps': 80}, {'States': 480197, 'Choices': 480497, 'Transitions': 1747393, 'aq_run_time_mopmc_cpu': 5.084029075689614, 'max_timesteps': 100}, {'States': 691417, 'Choices': 691777, 'Transitions': 2519233, 'aq_run_time_mopmc_cpu': 8.622067514806986, 'max_timesteps': 120}, {'States': 941037, 'Choices': 941457, 'Transitions': 3431873, 'aq_run_time_mopmc_cpu': 13.733757476322353, 'max_timesteps': 140}, {'States': 1229057, 'Choices': 1229537, 'Transitions': 4485313, 'aq_run_time_mopmc_cpu': 20.645712467841804, 'max_timesteps': 160}, {'States': 1555477, 'Choices': 1556017, 'Transitions': 5679553, 'aq_run_time_mopmc_cpu': 29.15642464440316, 'max_timesteps': 180}, {'States': 1920297, 'Choices': 1920897, 'Transitions': 7014593, 'aq_run_time_mopmc_cpu': 40.37312653847039, 'max_timesteps': 200}]

# %%
mopmc_gpu_ccq_results= run_experiment(mopmc_executable, switch_model_list, switch_property, "mopmc", "ccq")
mopmc_gpu_ccq_results.sort(key= lambda item: item['max_timesteps'])
print(f"\nMOPMC-GPU Convex Query Results:")
print(mopmc_gpu_ccq_results)
# Out:
# Running mopmc command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/model_size_eval_input/switch_model_20.prism -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/model_size_eval_input/switch_prop_achievable.props -q convex
# Running mopmc command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/model_size_eval_input/switch_model_120.prism -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/model_size_eval_input/switch_prop_achievable.props -q convex
# Running mopmc command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/model_size_eval_input/switch_model_200.prism -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/model_size_eval_input/switch_prop_achievable.props -q convex
# Running mopmc command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/model_size_eval_input/switch_model_100.prism -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/model_size_eval_input/switch_prop_achievable.props -q convex
# Running mopmc command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/model_size_eval_input/switch_model_140.prism -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/model_size_eval_input/switch_prop_achievable.props -q convex
# Running mopmc command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/model_size_eval_input/switch_model_80.prism -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/model_size_eval_input/switch_prop_achievable.props -q convex
# Running mopmc command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/model_size_eval_input/switch_model_60.prism -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/model_size_eval_input/switch_prop_achievable.props -q convex
# Running mopmc command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/model_size_eval_input/switch_model_180.prism -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/model_size_eval_input/switch_prop_achievable.props -q convex
# Running mopmc command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/model_size_eval_input/switch_model_160.prism -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/model_size_eval_input/switch_prop_achievable.props -q convex
# Running mopmc command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/model_size_eval_input/switch_model_40.prism -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/model_size_eval_input/switch_prop_achievable.props -q convex
#
# MOPMC-GPU Convex Query Results:
# [{'States': 19317, 'Choices': 19377, 'Transitions': 68033, 'ccq_loop_count_mopmc': 42, 'ccq_run_time_mopmc': 0.6793409269303083, 'max_timesteps': 20}, {'States': 76937, 'Choices': 77057, 'Transitions': 276673, 'ccq_loop_count_mopmc': 52, 'ccq_run_time_mopmc': 2.0892264507710934, 'max_timesteps': 40}, {'States': 172957, 'Choices': 173137, 'Transitions': 626113, 'ccq_loop_count_mopmc': 33, 'ccq_run_time_mopmc': 3.93468873295933, 'max_timesteps': 60}, {'States': 307377, 'Choices': 307617, 'Transitions': 1116353, 'ccq_loop_count_mopmc': 55, 'ccq_run_time_mopmc': 12.479645268060267, 'max_timesteps': 80}, {'States': 480197, 'Choices': 480497, 'Transitions': 1747393, 'ccq_loop_count_mopmc': 200, 'ccq_run_time_mopmc': 75.5445310799405, 'max_timesteps': 100}, {'States': 691417, 'Choices': 691777, 'Transitions': 2519233, 'ccq_loop_count_mopmc': 200, 'ccq_run_time_mopmc': 122.59818400721997, 'max_timesteps': 120}, {'States': 941037, 'Choices': 941457, 'Transitions': 3431873, 'ccq_loop_count_mopmc': 24, 'ccq_run_time_mopmc': 28.569517821073532, 'max_timesteps': 140}, {'States': 1229057, 'Choices': 1229537, 'Transitions': 4485313, 'ccq_loop_count_mopmc': 21, 'ccq_run_time_mopmc': 36.87374788802117, 'max_timesteps': 160}, {'States': 1555477, 'Choices': 1556017, 'Transitions': 5679553, 'ccq_loop_count_mopmc': 33, 'ccq_run_time_mopmc': 73.9280946739018, 'max_timesteps': 180}, {'States': 1920297, 'Choices': 1920897, 'Transitions': 7014593, 'ccq_loop_count_mopmc': 30, 'ccq_run_time_mopmc': 92.31780830211937, 'max_timesteps': 200}]

# %%
mopmc_cpu_ccq_results= run_experiment(mopmc_executable, switch_model_list, switch_property, "mopmc_cpu", "ccq")
mopmc_cpu_ccq_results.sort(key= lambda item: item['max_timesteps'])
print(f"\nMOPMC-CPU Convex Query Results:")
print(mopmc_cpu_ccq_results)
# Out:
# Running mopmc_cpu command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/model_size_eval_input/switch_model_20.prism -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/model_size_eval_input/switch_prop_achievable.props -q convex -v standard
# Running mopmc_cpu command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/model_size_eval_input/switch_model_120.prism -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/model_size_eval_input/switch_prop_achievable.props -q convex -v standard
# Running mopmc_cpu command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/model_size_eval_input/switch_model_200.prism -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/model_size_eval_input/switch_prop_achievable.props -q convex -v standard
# Running mopmc_cpu command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/model_size_eval_input/switch_model_100.prism -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/model_size_eval_input/switch_prop_achievable.props -q convex -v standard
# Running mopmc_cpu command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/model_size_eval_input/switch_model_140.prism -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/model_size_eval_input/switch_prop_achievable.props -q convex -v standard
# Running mopmc_cpu command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/model_size_eval_input/switch_model_80.prism -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/model_size_eval_input/switch_prop_achievable.props -q convex -v standard
# Running mopmc_cpu command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/model_size_eval_input/switch_model_60.prism -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/model_size_eval_input/switch_prop_achievable.props -q convex -v standard
# Running mopmc_cpu command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/model_size_eval_input/switch_model_180.prism -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/model_size_eval_input/switch_prop_achievable.props -q convex -v standard
# Running mopmc_cpu command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/model_size_eval_input/switch_model_160.prism -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/model_size_eval_input/switch_prop_achievable.props -q convex -v standard
# Running mopmc_cpu command: /home/guoxin/CLionProjects/mopmc-dev-v3/build/mopmc -m /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/model_size_eval_input/switch_model_40.prism -p /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/model_size_eval_input/switch_prop_achievable.props -q convex -v standard
#
# MOPMC-CPU Convex Query Results:
# [{'States': 19317, 'Choices': 19377, 'Transitions': 68033, 'ccq_loop_count_mopmc_cpu': 40, 'ccq_run_time_mopmc_cpu': 0.9968819264322519, 'max_timesteps': 20}, {'States': 76937, 'Choices': 77057, 'Transitions': 276673, 'ccq_loop_count_mopmc_cpu': 40, 'ccq_run_time_mopmc_cpu': 6.8313918597996235, 'max_timesteps': 40}, {'States': 172957, 'Choices': 173137, 'Transitions': 626113, 'ccq_loop_count_mopmc_cpu': 200, 'ccq_run_time_mopmc_cpu': 100.25671931914985, 'max_timesteps': 60}, {'States': 307377, 'Choices': 307617, 'Transitions': 1116353, 'ccq_loop_count_mopmc_cpu': 71, 'ccq_run_time_mopmc_cpu': 96.41214486770332, 'max_timesteps': 80}, {'States': 480197, 'Choices': 480497, 'Transitions': 1747393, 'ccq_loop_count_mopmc_cpu': 200, 'ccq_run_time_mopmc_cpu': 576.0209752265364, 'max_timesteps': 100}, {'States': 691417, 'Choices': 691777, 'Transitions': 2519233, 'ccq_loop_count_mopmc_cpu': 21, 'ccq_run_time_mopmc_cpu': 122.49835540447384, 'max_timesteps': 120}, {'States': 941037, 'Choices': 941457, 'Transitions': 3431873, 'ccq_loop_count_mopmc_cpu': 20, 'ccq_run_time_mopmc_cpu': 187.79090643394738, 'max_timesteps': 140}, {'States': 1229057, 'Choices': 1229537, 'Transitions': 4485313, 'ccq_loop_count_mopmc_cpu': 18, 'ccq_run_time_mopmc_cpu': 267.556967061013, 'max_timesteps': 160}, {'States': 1555477, 'Choices': 1556017, 'Transitions': 5679553, 'ccq_loop_count_mopmc_cpu': 35, 'ccq_run_time_mopmc_cpu': 703.0512643167749, 'max_timesteps': 180}, {'States': 1920297, 'Choices': 1920897, 'Transitions': 7014593, 'ccq_loop_count_mopmc_cpu': 26, 'ccq_run_time_mopmc_cpu': 740.6824996136129, 'max_timesteps': 200}]

# %%
mopmc_gpu_ucq_results= run_experiment(mopmc_executable, switch_model_list, switch_property, "mopmc", "ucq")
mopmc_gpu_ucq_results.sort(key= lambda item: item['max_timesteps'])
print(f"\nMOPMC-GPU (Unconstrained) Convex Query Results:")
print(mopmc_gpu_ucq_results)

# %%
print(mopmc_gpu_ucq_results)
# Out:
# [{'States': 19317, 'Choices': 19377, 'Transitions': 68033, 'ucq_run_time_mopmc': 0.3635582057759166, 'max_timesteps': 20}, {'States': 76937, 'Choices': 77057, 'Transitions': 276673, 'ucq_run_time_mopmc': 0.6320135155692697, 'max_timesteps': 40}, {'States': 172957, 'Choices': 173137, 'Transitions': 626113, 'ucq_run_time_mopmc': 1.3587223328649998, 'max_timesteps': 60}, {'States': 307377, 'Choices': 307617, 'Transitions': 1116353, 'ucq_run_time_mopmc': 2.9655976807698607, 'max_timesteps': 80}, {'States': 480197, 'Choices': 480497, 'Transitions': 1747393, 'ucq_run_time_mopmc': 4.334872174076736, 'max_timesteps': 100}, {'States': 691417, 'Choices': 691777, 'Transitions': 2519233, 'ucq_run_time_mopmc': 9.175834064371884, 'max_timesteps': 120}, {'States': 941037, 'Choices': 941457, 'Transitions': 3431873, 'ucq_run_time_mopmc': 192.1141032492742, 'max_timesteps': 140}, {'States': 1229057, 'Choices': 1229537, 'Transitions': 4485313, 'ucq_run_time_mopmc': 280.88248891662806, 'max_timesteps': 160}, {'States': 1555477, 'Choices': 1556017, 'Transitions': 5679553, 'ucq_run_time_mopmc': 392.2888965597376, 'max_timesteps': 180}, {'States': 1920297, 'Choices': 1920897, 'Transitions': 7014593, 'ucq_run_time_mopmc': 530.356351967901, 'max_timesteps': 200}]

# %%
mopmc_cpu_ucq_results= run_experiment(mopmc_executable, switch_model_list, switch_property, "mopmc_cpu", "ucq")
mopmc_cpu_ucq_results.sort(key= lambda item: item['max_timesteps'])
print(f"\nMOPMC-CPU (Unconstrained) Convex Query Results:")
print(mopmc_cpu_ucq_results)

# %%
storm_results= run_experiment(storm_executable, switch_model_list, switch_property, "storm")
storm_results.sort(key= lambda item: item['max_timesteps'])
print(f"\nStorm Results:")
print(storm_results)
# Out:
# Running storm command: /home/guoxin/Downloads/storm/build/bin/storm --prism switch_model_20.prism --prop /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/switch_prop_achievable.props
# Running storm command: /home/guoxin/Downloads/storm/build/bin/storm --prism switch_model_120.prism --prop /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/switch_prop_achievable.props
# Running storm command: /home/guoxin/Downloads/storm/build/bin/storm --prism switch_model_200.prism --prop /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/switch_prop_achievable.props
# Running storm command: /home/guoxin/Downloads/storm/build/bin/storm --prism switch_model_100.prism --prop /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/switch_prop_achievable.props
# Running storm command: /home/guoxin/Downloads/storm/build/bin/storm --prism switch_model_140.prism --prop /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/switch_prop_achievable.props
# Running storm command: /home/guoxin/Downloads/storm/build/bin/storm --prism switch_model_80.prism --prop /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/switch_prop_achievable.props
# Running storm command: /home/guoxin/Downloads/storm/build/bin/storm --prism switch_model_60.prism --prop /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/switch_prop_achievable.props
# Running storm command: /home/guoxin/Downloads/storm/build/bin/storm --prism switch_model_180.prism --prop /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/switch_prop_achievable.props
# Running storm command: /home/guoxin/Downloads/storm/build/bin/storm --prism switch_model_160.prism --prop /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/switch_prop_achievable.props
# Running storm command: /home/guoxin/Downloads/storm/build/bin/storm --prism switch_model_40.prism --prop /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/switch_prop_achievable.props
#
# Storm Results:
# [{'States': 19317, 'Choices': 19377, 'Transitions': 68033, 'aq_run_time_storm': 0.22546925954520702, 'max_timesteps': 20}, {'States': 76937, 'Choices': 77057, 'Transitions': 276673, 'aq_run_time_storm': 0.6068280171602964, 'max_timesteps': 40}, {'States': 172957, 'Choices': 173137, 'Transitions': 626113, 'aq_run_time_storm': 1.3083887910470366, 'max_timesteps': 60}, {'States': 307377, 'Choices': 307617, 'Transitions': 1116353, 'aq_run_time_storm': 2.4286149004474282, 'max_timesteps': 80}, {'States': 480197, 'Choices': 480497, 'Transitions': 1747393, 'aq_run_time_storm': 3.9102767817676067, 'max_timesteps': 100}, {'States': 691417, 'Choices': 691777, 'Transitions': 2519233, 'aq_run_time_storm': 6.185698454268277, 'max_timesteps': 120}, {'States': 941037, 'Choices': 941457, 'Transitions': 3431873, 'aq_run_time_storm': 8.768013491295278, 'max_timesteps': 140}, {'States': 1229057, 'Choices': 1229537, 'Transitions': 4485313, 'aq_run_time_storm': 12.012424918822944, 'max_timesteps': 160}, {'States': 1555477, 'Choices': 1556017, 'Transitions': 5679553, 'aq_run_time_storm': 16.061062367632985, 'max_timesteps': 180}, {'States': 1920297, 'Choices': 1920897, 'Transitions': 7014593, 'aq_run_time_storm': 20.93078555725515, 'max_timesteps': 200}]

# %%
prism_results = run_experiment(prism_executable, switch_model_list, switch_property, "prism")
prism_results.sort(key= lambda item: item['max_timesteps'])
print(f"\nPRISM Results:")
print(prism_results)
# Out:
# Running prism command: /home/guoxin/Downloads/prism-4.4-linux64/bin/prism switch_model_20.prism /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/switch_prop_achievable.props
# Running prism command: /home/guoxin/Downloads/prism-4.4-linux64/bin/prism switch_model_120.prism /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/switch_prop_achievable.props
# Running prism command: /home/guoxin/Downloads/prism-4.4-linux64/bin/prism switch_model_200.prism /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/switch_prop_achievable.props
# Running prism command: /home/guoxin/Downloads/prism-4.4-linux64/bin/prism switch_model_100.prism /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/switch_prop_achievable.props
# Running prism command: /home/guoxin/Downloads/prism-4.4-linux64/bin/prism switch_model_140.prism /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/switch_prop_achievable.props
# Running prism command: /home/guoxin/Downloads/prism-4.4-linux64/bin/prism switch_model_80.prism /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/switch_prop_achievable.props
# Running prism command: /home/guoxin/Downloads/prism-4.4-linux64/bin/prism switch_model_60.prism /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/switch_prop_achievable.props
# Running prism command: /home/guoxin/Downloads/prism-4.4-linux64/bin/prism switch_model_180.prism /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/switch_prop_achievable.props
# Running prism command: /home/guoxin/Downloads/prism-4.4-linux64/bin/prism switch_model_160.prism /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/switch_prop_achievable.props
# Running prism command: /home/guoxin/Downloads/prism-4.4-linux64/bin/prism switch_model_40.prism /home/guoxin/PycharmProjects/realtime-drl-switch/scripts/tool_evaluation/switch_prop_achievable.props
#
# PRISM Results:
# [{'States': 19317, 'Choices': 19377, 'Transitions': 68033, 'aq_run_time_prism': 1.3207711232826114, 'max_timesteps': 20}, {'States': 76937, 'Choices': 77057, 'Transitions': 276673, 'aq_run_time_prism': 1.4532131599262357, 'max_timesteps': 40}, {'States': 172957, 'Choices': 173137, 'Transitions': 626113, 'aq_run_time_prism': 3.4107356322929263, 'max_timesteps': 60}, {'States': 307377, 'Choices': 307617, 'Transitions': 1116353, 'aq_run_time_prism': 7.331048397347331, 'max_timesteps': 80}, {'States': 480197, 'Choices': 480497, 'Transitions': 1747393, 'aq_run_time_prism': 13.202663938514888, 'max_timesteps': 100}, {'States': 691417, 'Choices': 691777, 'Transitions': 2519233, 'aq_run_time_prism': 22.367229821160436, 'max_timesteps': 120}, {'States': 941037, 'Choices': 941457, 'Transitions': 3431873, 'aq_run_time_prism': 34.12038508988917, 'max_timesteps': 140}, {'States': 1229057, 'Choices': 1229537, 'Transitions': 4485313, 'aq_run_time_prism': 50.16400877851993, 'max_timesteps': 160}, {'States': 1555477, 'Choices': 1556017, 'Transitions': 5679553, 'aq_run_time_prism': 70.68206166662276, 'max_timesteps': 180}, {'States': 1920297, 'Choices': 1920897, 'Transitions': 7014593, 'aq_run_time_prism': 95.86971587501466, 'max_timesteps': 200}]

# %%
combined_results= []
for d0, d1, d2, d3, d4, d5 in zip(storm_results, prism_results, 
                                  mopmc_gpu_aq_results, mopmc_cpu_aq_results,
                                  mopmc_gpu_ccq_results, mopmc_cpu_ccq_results):
    combined_dict = d0.copy()
    combined_dict.update(d1)
    combined_dict.update(d2)
    combined_dict.update(d3)
    combined_dict.update(d4)
    combined_dict.update(d5)
    #combined_dict.pop('tool')
    combined_results.append(combined_dict)

import pandas as pd
combined_results_df = pd.DataFrame(combined_results)
print(f"current column names: {combined_results_df.columns}")
combined_results_df['ccq_run_time_mopmc_per_it'] = combined_results_df['ccq_run_time_mopmc'] / combined_results_df['ccq_loop_count_mopmc']
combined_results_df['ccq_run_time_mopmc_cpu_per_it'] = combined_results_df['ccq_run_time_mopmc_cpu'] / combined_results_df['ccq_loop_count_mopmc_cpu']
new_column_order = ['max_timesteps', 'States', 'Choices', 'Transitions', 
                    'aq_run_time_storm', 'aq_run_time_prism', 
                    'aq_run_time_mopmc', 'aq_run_time_mopmc_cpu', 
                    'ccq_run_time_mopmc', 'ccq_loop_count_mopmc' ,'ccq_run_time_mopmc_per_it', 
                    'ccq_run_time_mopmc_cpu', 'ccq_loop_count_mopmc_cpu', 'ccq_run_time_mopmc_cpu_per_it']
combined_results_df = combined_results_df[new_column_order]

num_columns = ['aq_run_time_storm', 'aq_run_time_prism', 'aq_run_time_mopmc',
       'aq_run_time_mopmc_cpu', 'ccq_run_time_mopmc','ccq_run_time_mopmc_per_it',
       'ccq_run_time_mopmc_cpu', 'ccq_run_time_mopmc_cpu_per_it']
combined_results_df[num_columns] = combined_results_df[num_columns].round(2)
print(combined_results_df)
# Out:
# current column names: Index(['States', 'Choices', 'Transitions', 'aq_run_time_storm',
#        'max_timesteps', 'aq_run_time_prism', 'aq_loop_count_mopmc',
#        'aq_run_time_mopmc', 'aq_run_time_mopmc_cpu', 'ccq_loop_count_mopmc',
#        'ccq_run_time_mopmc', 'ccq_loop_count_mopmc_cpu',
#        'ccq_run_time_mopmc_cpu'],
#       dtype='object')
#    max_timesteps   States  Choices  Transitions  aq_run_time_storm  \
# 0             20    19317    19377        68033               0.23
# 1             40    76937    77057       276673               0.61
# 2             60   172957   173137       626113               1.31
# 3             80   307377   307617      1116353               2.43
# 4            100   480197   480497      1747393               3.91
# 5            120   691417   691777      2519233               6.19
# 6            140   941037   941457      3431873               8.77
# 7            160  1229057  1229537      4485313              12.01
# 8            180  1555477  1556017      5679553              16.06
# 9            200  1920297  1920897      7014593              20.93
#
#    aq_run_time_prism  aq_run_time_mopmc  aq_run_time_mopmc_cpu  \
# 0               1.32               0.35                   0.17
# 1               1.45               0.45                   0.49
# 2               3.41               0.94                   1.25
# 3               7.33               1.70                   2.70
# 4              13.20               2.73                   5.08
# 5              22.37               4.27                   8.62
# 6              34.12               6.14                  13.73
# 7              50.16               8.82                  20.65
# 8              70.68              12.07                  29.16
# 9              95.87              16.17                  40.37
#
#    ccq_run_time_mopmc  ccq_loop_count_mopmc  ccq_run_time_mopmc_per_it  \
# 0                0.68                    42                       0.02
# 1                2.09                    52                       0.04
# 2                3.93                    33                       0.12
# 3               12.48                    55                       0.23
# 4               75.54                   200                       0.38
# 5              122.60                   200                       0.61
# 6               28.57                    24                       1.19
# 7               36.87                    21                       1.76
# 8               73.93                    33                       2.24
# 9               92.32                    30                       3.08
#
#    ccq_run_time_mopmc_cpu  ccq_loop_count_mopmc_cpu  \
# 0                    1.00                        40
# 1                    6.83                        40
# 2                  100.26                       200
# 3                   96.41                        71
# 4                  576.02                       200
# 5                  122.50                        21
# 6                  187.79                        20
# 7                  267.56                        18
# 8                  703.05                        35
# 9                  740.68                        26
#
#    ccq_run_time_mopmc_cpu_per_it
# 0                           0.02
# 1                           0.17
# 2                           0.50
# 3                           1.36
# 4                           2.88
# 5                           5.83
# 6                           9.39
# 7                          14.86
# 8                          20.09
# 9                          28.49

# %%
switch_model_200 = os.path.join(current_folder, 'switch_model_200.prism')
mopmc_ccq_command_switch_model_200 = f"{mopmc_executable} -m {switch_model_200} -p {switch_property} -q convex -c y"
! $mopmc_ccq_command_switch_model_200
# Out:
# --Model Building--
# States:	1920297
# Choices:	1920897
# Transitions:	7014593
# ____ CUDA INITIALIZING ____
# [Main loop] Iteration: 0
# [Const. Sat. verification] Verification successful: The point is indeed in all half-spaces.
# [Project gradient - interior phase] finds minimum point at iteration: 1 (distance: 1.0071262)
# [Minimum norm point optimization] exits for one vertex
# [Main loop] Iteration: 1
# [Main loop] Iteration: 2
# [Const. Sat. verification] Verification successful: The point is indeed in all half-spaces.
# [Project gradient - interior phase] finds minimum point at iteration: 1 (distance: 1.004818211)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 1 (distance: 4.658368223e-07)
# [Main loop] Iteration: 3
# [Main loop] Iteration: 4
# [Const. Sat. verification] Verification successful: The point is indeed in all half-spaces.
# [Project gradient - interior phase] finds minimum point at iteration: 1 (distance: 1.005607511)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 68 (distance: 3.449259507e-08)
# [Main loop] Iteration: 5
# [Main loop] Iteration: 6
# [Const. Sat. verification] Verification successful: The point is indeed in all half-spaces.
# [Project gradient - interior phase] finds minimum point at iteration: 1 (distance: 1.004818211)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 31 (distance: 2.892160583e-07)
# [Main loop] Iteration: 7
# [Main loop] Iteration: 8
# [Const. Sat. verification] Verification successful: The point is indeed in all half-spaces.
# [Project gradient - interior phase] finds minimum point at iteration: 1 (distance: 1.004818211)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 51 (distance: 1.545529233e-07)
# [Main loop] Iteration: 9
# [Main loop] Iteration: 10
# [Const. Sat. verification] Verification successful: The point is indeed in all half-spaces.
# [Project gradient - interior phase] finds minimum point at iteration: 1 (distance: 1.005444404)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 10 (distance: 2.061395754e-08)
# [Main loop] Iteration: 11
# [Const. Sat. verification] Verification successful: The point is indeed in all half-spaces.
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 1.005601431)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 4 (distance: 1.660947733e-07)
# [Main loop] Iteration: 12
# [Const. Sat. verification] Verification successful: The point is indeed in all half-spaces.
# [Project gradient - interior phase] finds minimum point at iteration: 1 (distance: 1.005774791)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 86 (distance: 1.006837636e-08)
# [Main loop] Iteration: 13
# [Const. Sat. verification] Verification successful: The point is indeed in all half-spaces.
# [Project gradient - interior phase] finds minimum point at iteration: 1 (distance: 1.005739337)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 2 (distance: 1.090459434e-09)
# [Main loop] Iteration: 14
# [Const. Sat. verification] Verification successful: The point is indeed in all half-spaces.
# [Project gradient - interior phase] finds minimum point at iteration: 1 (distance: 1.005814091)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 6 (distance: 1.512766826e-10)
# [Main loop] Iteration: 15
# [Const. Sat. verification] Verification successful: The point is indeed in all half-spaces.
# [Project gradient - interior phase] finds minimum point at iteration: 1 (distance: 1.005866282)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 97 (distance: 2.013849579e-08)
# [Main loop] Iteration: 16
# [Const. Sat. verification] Verification successful: The point is indeed in all half-spaces.
# [Project gradient - interior phase] finds minimum point at iteration: 1 (distance: 1.005835334)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 28 (distance: 3.900284591e-09)
# [Main loop] Iteration: 17
# [Const. Sat. verification] Verification successful: The point is indeed in all half-spaces.
# [Project gradient - interior phase] finds minimum point at iteration: 1 (distance: 1.005812624)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 32 (distance: 1.397029615e-09)
# [Main loop] Iteration: 18
# [Const. Sat. verification] Verification successful: The point is indeed in all half-spaces.
# [Project gradient - interior phase] finds minimum point at iteration: 1 (distance: 1.005812716)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 12 (distance: 1.582220981e-10)
# [Main loop] Iteration: 19
# [Const. Sat. verification] Verification successful: The point is indeed in all half-spaces.
# [Project gradient - interior phase] finds minimum point at iteration: 1 (distance: 1.005806583)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 14 (distance: 1.624982115e-10)
# [Main loop] Iteration: 20
# [Const. Sat. verification] Verification successful: The point is indeed in all half-spaces.
# [Project gradient - interior phase] finds minimum point at iteration: 1 (distance: 1.005788501)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 12 (distance: 2.55019465e-08)
# [Main loop] Iteration: 21
# [Const. Sat. verification] Verification successful: The point is indeed in all half-spaces.
# [Project gradient - interior phase] finds minimum point at iteration: 1 (distance: 1.005813755)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 65 (distance: 4.480823723e-10)
# [Main loop] Iteration: 22
# [Const. Sat. verification] Verification successful: The point is indeed in all half-spaces.
# [Project gradient - interior phase] finds minimum point at iteration: 1 (distance: 1.005830146)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 14 (distance: 3.510062367e-09)
# [Main loop] Iteration: 23
# [Const. Sat. verification] Verification successful: The point is indeed in all half-spaces.
# [Project gradient - interior phase] finds minimum point at iteration: 1 (distance: 1.005830146)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 5 (distance: 3.441581755e-09)
# [Main loop] Iteration: 24
# [Const. Sat. verification] Verification successful: The point is indeed in all half-spaces.
# [Project gradient - interior phase] finds minimum point at iteration: 1 (distance: 1.005912029)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 22 (distance: 2.137671303e-14)
# [Main loop] Iteration: 25
# [Const. Sat. verification] Verification successful: The point is indeed in all half-spaces.
# [Project gradient - interior phase] finds minimum point at iteration: 1 (distance: 1.005912029)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 0 (distance: 2.137281666e-14)
# [Main loop] Iteration: 26
# [Const. Sat. verification] Verification successful: The point is indeed in all half-spaces.
# [Project gradient - interior phase] finds minimum point at iteration: 1 (distance: 1.005912029)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 0 (distance: 2.137281667e-14)
# [Main loop] Iteration: 27
# [Const. Sat. verification] Verification successful: The point is indeed in all half-spaces.
# [Project gradient - interior phase] finds minimum point at iteration: 1 (distance: 1.005912029)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 0 (distance: 2.137281667e-14)
# [Main loop] Iteration: 28
# [Const. Sat. verification] Verification successful: The point is indeed in all half-spaces.
# [Project gradient - interior phase] finds minimum point at iteration: 1 (distance: 1.005912029)
# [Main loop] exits due to small inner/outer points update (l1 norm <= 1e-30)
# ____ CUDA EXIT ____
# ----------------------------------------------
# --Convex Query Result--
# with constraint? true
# terminates after 29 iteration(s)
# Estimated optimal inner point: [1.893566443 0.5728643475 0.2345629563 0.2342259666]
# Estimated optimal outer point: [1.893566279 0.5728641075 0.2345629266 0.2342259778]
# Approximate distance (at inner point): 1.005912255
# Approximate distance (at outer point): 1.005912029
#
# Inner point satisfying constraints? true
# Outer point satisfying constraints? true
# ----------------------------------------------
# --TIME STATISTICS--
# Time for model construction: 12.935 second(s).
# Time for data transformation: 0.326 second(s).
# Time for model checking: 75.111 second(s), 2.590 per iteration.
# Total time: 88.372 second(s).

# %%
switch_model_200 = os.path.join(current_folder, 'switch_model_200.prism')
mopmc_ucq_command_switch_model_200 = f"{mopmc_executable} -m {switch_model_200} -p {switch_property} -q convex -c n"
! $mopmc_ucq_command_switch_model_200
# Out:
# --Model Building--
# States:	1920297
# Choices:	1920897
# Transitions:	7014593
# ____ CUDA INITIALIZING ____
# [Main loop] Iteration: 0
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 0)
# [Minimum norm point optimization] exits for one vertex
# [Main loop] Iteration: 1
# [Main loop] Iteration: 2
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 9.595566029e-08)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 1 (distance: 2.848689447e-07)
# [Main loop] Iteration: 3
# [Main loop] Iteration: 4
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.665356212e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 0 (distance: 6.823016175e-10)
# [Main loop] Iteration: 5
# [Main loop] Iteration: 6
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.664827674e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 0 (distance: 6.823016171e-10)
# [Main loop] Iteration: 7
# [Main loop] Iteration: 8
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.66433142e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 0 (distance: 6.823016171e-10)
# [Main loop] Iteration: 9
# [Main loop] Iteration: 10
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.663865478e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 0 (distance: 6.823016171e-10)
# [Main loop] Iteration: 11
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.663427997e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 0 (distance: 6.823016171e-10)
# [Main loop] Iteration: 12
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.663017238e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 0 (distance: 6.823016171e-10)
# [Main loop] Iteration: 13
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.662631569e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 0 (distance: 6.823016171e-10)
# [Main loop] Iteration: 14
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.662269458e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 0 (distance: 6.823016171e-10)
# [Main loop] Iteration: 15
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.661929465e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 0 (distance: 6.823016169e-10)
# [Main loop] Iteration: 16
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.661610239e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 0 (distance: 6.82301617e-10)
# [Main loop] Iteration: 17
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.661310512e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 0 (distance: 6.82301617e-10)
# [Main loop] Iteration: 18
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.661029094e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 0 (distance: 6.82301617e-10)
# [Main loop] Iteration: 19
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.660764865e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 0 (distance: 6.82301617e-10)
# [Main loop] Iteration: 20
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.660516775e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 0 (distance: 6.82301617e-10)
# [Main loop] Iteration: 21
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.660283839e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 0 (distance: 6.82301617e-10)
# [Main loop] Iteration: 22
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.660065132e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 0 (distance: 6.82301617e-10)
# [Main loop] Iteration: 23
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.659859784e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 0 (distance: 6.82301617e-10)
# [Main loop] Iteration: 24
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.659666978e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 0 (distance: 6.82301617e-10)
# [Main loop] Iteration: 25
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.65948595e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 0 (distance: 6.82301617e-10)
# [Main loop] Iteration: 26
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.659315979e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 0 (distance: 6.82301617e-10)
# [Main loop] Iteration: 27
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.659156391e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 0 (distance: 6.82301617e-10)
# [Main loop] Iteration: 28
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.65900655e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 0 (distance: 6.82301617e-10)
# [Main loop] Iteration: 29
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.658865862e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 0 (distance: 6.82301617e-10)
# [Main loop] Iteration: 30
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.658733767e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 0 (distance: 6.82301617e-10)
# [Main loop] Iteration: 31
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.658609741e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 0 (distance: 6.82301617e-10)
# [Main loop] Iteration: 32
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.658493291e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 0 (distance: 6.82301617e-10)
# [Main loop] Iteration: 33
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.658383954e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 0 (distance: 6.82301617e-10)
# [Main loop] Iteration: 34
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.658281295e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 0 (distance: 6.82301617e-10)
# [Main loop] Iteration: 35
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.658184907e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 0 (distance: 6.82301617e-10)
# [Main loop] Iteration: 36
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.658094407e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 0 (distance: 6.82301617e-10)
# [Main loop] Iteration: 37
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.658009434e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 0 (distance: 6.82301617e-10)
# [Main loop] Iteration: 38
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.657929652e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 0 (distance: 6.82301617e-10)
# [Main loop] Iteration: 39
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.657854743e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 0 (distance: 6.82301617e-10)
# [Main loop] Iteration: 40
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.657784409e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 0 (distance: 6.82301617e-10)
# [Main loop] Iteration: 41
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.657718372e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 0 (distance: 6.82301617e-10)
# [Main loop] Iteration: 42
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.657656369e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 0 (distance: 6.82301617e-10)
# [Main loop] Iteration: 43
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.657598152e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 0 (distance: 6.82301617e-10)
# [Main loop] Iteration: 44
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.657543492e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 0 (distance: 6.82301617e-10)
# [Main loop] Iteration: 45
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.65749217e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 0 (distance: 6.82301617e-10)
# [Main loop] Iteration: 46
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.657443984e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 0 (distance: 6.82301617e-10)
# [Main loop] Iteration: 47
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.65739874e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 0 (distance: 6.82301617e-10)
# [Main loop] Iteration: 48
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.65735626e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 0 (distance: 6.822981296e-10)
# [Main loop] Iteration: 49
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.657724603e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 0 (distance: 6.809810355e-10)
# [Main loop] Iteration: 50
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.658185466e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 0 (distance: 6.793692842e-10)
# [Main loop] Iteration: 51
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.658713479e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 0 (distance: 6.775435895e-10)
# [Main loop] Iteration: 52
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.659325599e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 0 (distance: 6.754492001e-10)
# [Main loop] Iteration: 53
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.660045875e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 0 (distance: 6.730087708e-10)
# [Main loop] Iteration: 54
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.660791229e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 0 (distance: 6.704847785e-10)
# [Main loop] Iteration: 55
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.661534822e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 0 (distance: 6.679581418e-10)
# [Main loop] Iteration: 56
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.662478837e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 0 (distance: 6.647825852e-10)
# [Main loop] Iteration: 57
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.663736346e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 0 (distance: 6.605932262e-10)
# [Main loop] Iteration: 58
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.665526272e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 0 (distance: 6.546843963e-10)
# [Main loop] Iteration: 59
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.668362825e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 0 (distance: 6.453943809e-10)
# [Main loop] Iteration: 60
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.672286719e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 0 (distance: 6.321511248e-10)
# [Main loop] Iteration: 61
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.680818111e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 220 (distance: 1.943494394e-10)
# [Main loop] Iteration: 62
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.679576016e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 44 (distance: 4.040544541e-11)
# [Main loop] Iteration: 63
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.679323557e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 26 (distance: 1.054909925e-11)
# [Main loop] Iteration: 64
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.679252715e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 8 (distance: 8.939417576e-12)
# [Main loop] Iteration: 65
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.679179424e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 5 (distance: 8.355002033e-12)
# [Main loop] Iteration: 66
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.67911009e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 2 (distance: 8.337908405e-12)
# [Main loop] Iteration: 67
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.679040946e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 2 (distance: 8.321098844e-12)
# [Main loop] Iteration: 68
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.678972493e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 2 (distance: 8.304273954e-12)
# [Main loop] Iteration: 69
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.678904724e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 2 (distance: 8.287430497e-12)
# [Main loop] Iteration: 70
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.678837633e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 2 (distance: 8.270565824e-12)
# [Main loop] Iteration: 71
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.678771215e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 2 (distance: 8.25367779e-12)
# [Main loop] Iteration: 72
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.678705462e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 2 (distance: 8.236764726e-12)
# [Main loop] Iteration: 73
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.678640368e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 2 (distance: 8.219825239e-12)
# [Main loop] Iteration: 74
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.678575928e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 5 (distance: 7.793161692e-12)
# [Main loop] Iteration: 75
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.678515217e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 2 (distance: 7.777637796e-12)
# [Main loop] Iteration: 76
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.678454713e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 2 (distance: 7.7622834e-12)
# [Main loop] Iteration: 77
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.678394796e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 2 (distance: 7.746900206e-12)
# [Main loop] Iteration: 78
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.678335461e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 2 (distance: 7.731487961e-12)
# [Main loop] Iteration: 79
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.678276702e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 2 (distance: 7.716046509e-12)
# [Main loop] Iteration: 80
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.678218515e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 2 (distance: 7.700575821e-12)
# [Main loop] Iteration: 81
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.678160894e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 2 (distance: 7.685075943e-12)
# [Main loop] Iteration: 82
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.678103834e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 2 (distance: 7.669546998e-12)
# [Main loop] Iteration: 83
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.67804733e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 5 (distance: 7.341382201e-12)
# [Main loop] Iteration: 84
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.677993638e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 2 (distance: 7.326891433e-12)
# [Main loop] Iteration: 85
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.677940154e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 2 (distance: 7.312515499e-12)
# [Main loop] Iteration: 86
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.677887177e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 2 (distance: 7.298112203e-12)
# [Main loop] Iteration: 87
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.677834702e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 2 (distance: 7.283681893e-12)
# [Main loop] Iteration: 88
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.677782726e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 2 (distance: 7.269224965e-12)
# [Main loop] Iteration: 89
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.677731245e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 2 (distance: 7.254741823e-12)
# [Main loop] Iteration: 90
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.677680253e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 2 (distance: 7.240232905e-12)
# [Main loop] Iteration: 91
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.677629747e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 2 (distance: 7.225698676e-12)
# [Main loop] Iteration: 92
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.677579723e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 2 (distance: 7.211139609e-12)
# [Main loop] Iteration: 93
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.677530175e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 5 (distance: 6.953228564e-12)
# [Main loop] Iteration: 94
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.677482785e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 2 (distance: 6.939461687e-12)
# [Main loop] Iteration: 95
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.677435594e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 2 (distance: 6.9257778e-12)
# [Main loop] Iteration: 96
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.677388843e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 2 (distance: 6.912071445e-12)
# [Main loop] Iteration: 97
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.677342529e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 2 (distance: 6.898343119e-12)
# [Main loop] Iteration: 98
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.677296648e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 2 (distance: 6.884593329e-12)
# [Main loop] Iteration: 99
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.677251196e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 2 (distance: 6.870822592e-12)
# [Main loop] Iteration: 100
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.677206169e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 2 (distance: 6.857031428e-12)
# [Main loop] Iteration: 101
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.677161563e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 2 (distance: 6.84322036e-12)
# [Main loop] Iteration: 102
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.677117376e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 2 (distance: 6.82938992e-12)
# [Main loop] Iteration: 103
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.677073603e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 2 (distance: 6.815540636e-12)
# [Main loop] Iteration: 104
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.677030241e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 5 (distance: 6.609235771e-12)
# [Main loop] Iteration: 105
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.676988556e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 2 (distance: 6.596009451e-12)
# [Main loop] Iteration: 106
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.676947058e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 2 (distance: 6.582846737e-12)
# [Main loop] Iteration: 107
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.676905943e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 2 (distance: 6.569667365e-12)
# [Main loop] Iteration: 108
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.676865206e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 2 (distance: 6.556472143e-12)
# [Main loop] Iteration: 109
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.676824846e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 2 (distance: 6.543262296e-12)
# [Main loop] Iteration: 110
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.676784858e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 2 (distance: 6.530038313e-12)
# [Main loop] Iteration: 111
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.676745239e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 2 (distance: 6.516800667e-12)
# [Main loop] Iteration: 112
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.676705987e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 2 (distance: 6.503549896e-12)
# [Main loop] Iteration: 113
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.676667098e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 2 (distance: 6.490286453e-12)
# [Main loop] Iteration: 114
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.676628569e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 2 (distance: 6.477010853e-12)
# [Main loop] Iteration: 115
# [Project gradient - interior phase] finds minimum point at iteration: 2 (distance: 6.676590398e-07)
# [Minimum norm point optimization] max margin separation hyperplane computed, terminates at iteration: 5 (distance: 6.307566841e-12)
# [Main loop] Iteration: 116
# ^C

# %%
mopmc_gpu_results_sorted = sorted(mopmc_gpu_results, key= lambda item: item['max_timesteps'])
mopmc_cpu_results_sorted = sorted(mopmc_cpu_results, key= lambda item: item['max_timesteps'])
prism_results_sorted = sorted(prism_results, key = lambda item: item['max_timesteps'])
storm_results_sorted = sorted(storm_results, key = lambda item: item['max_timesteps'])
mopmc_gpu_results_sorted
# Out:
# [{'tool': 'mopmc',
#   'States': 19317,
#   'Transitions': 68033,
#   'Choices': 19377,
#   'run_time_mopmc': 0.3350753728300333,
#   'max_timesteps': 20},
#  {'tool': 'mopmc',
#   'States': 76937,
#   'Transitions': 276673,
#   'Choices': 77057,
#   'run_time_mopmc': 0.49274621345102787,
#   'max_timesteps': 40},
#  {'tool': 'mopmc',
#   'States': 172957,
#   'Transitions': 626113,
#   'Choices': 173137,
#   'run_time_mopmc': 0.9564441032707691,
#   'max_timesteps': 60},
#  {'tool': 'mopmc',
#   'States': 307377,
#   'Transitions': 1116353,
#   'Choices': 307617,
#   'run_time_mopmc': 1.639373792335391,
#   'max_timesteps': 80},
#  {'tool': 'mopmc',
#   'States': 480197,
#   'Transitions': 1747393,
#   'Choices': 480497,
#   'run_time_mopmc': 2.6883487226441503,
#   'max_timesteps': 100},
#  {'tool': 'mopmc',
#   'States': 691417,
#   'Transitions': 2519233,
#   'Choices': 691777,
#   'run_time_mopmc': 4.185967640951276,
#   'max_timesteps': 120},
#  {'tool': 'mopmc',
#   'States': 941037,
#   'Transitions': 3431873,
#   'Choices': 941457,
#   'run_time_mopmc': 6.2182271564379334,
#   'max_timesteps': 140},
#  {'tool': 'mopmc',
#   'States': 1229057,
#   'Transitions': 4485313,
#   'Choices': 1229537,
#   'run_time_mopmc': 8.84371803700924,
#   'max_timesteps': 160},
#  {'tool': 'mopmc',
#   'States': 1555477,
#   'Transitions': 5679553,
#   'Choices': 1556017,
#   'run_time_mopmc': 12.034899872727692,
#   'max_timesteps': 180},
#  {'tool': 'mopmc',
#   'States': 1920297,
#   'Transitions': 7014593,
#   'Choices': 1920897,
#   'run_time_mopmc': 16.271992202848196,
#   'max_timesteps': 200}]
